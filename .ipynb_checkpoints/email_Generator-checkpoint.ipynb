# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    temperature=0,
    groq_api_key = 'api    model_name = "llama-3.3-70b-versatile"
)
response = llm.invoke("the person land on moon was..")
print(response.content)
# Out:
# The first person to land on the Moon was Neil Armstrong. He stepped out of the lunar module Eagle and onto the Moon's surface on July 20, 1969, as part of the Apollo 11 mission. Armstrong famously declared, "That's one small step for man, one giant leap for mankind," as he became the first human to set foot on the Moon.

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://jobs.nike.com/job/R-33460")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# Nike Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to main content
# Open Virtual Assistant
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# Career Areas
#
#
# Total Rewards
#
#
# Life@Nike
#
#
# Purpose
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
# Select a Language
#
#   Deutsch
#   English
#   Español (España)
#   Español (América Latina)
#   Français
#   Italiano
#   Nederlands
#   Polski
#   Tiếng Việt
#   Türkçe
#   简体中文
#   繁體中文
#   עִברִית
#   한국어
#   日本語
#
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close Menu
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
# Chat
#
#
#
#
#
#
#                                 Home
#
#
#
#
#                                 Career Areas
#
#
#
#
#                                 Total Rewards
#
#
#
#
#                                 Life@Nike
#
#
#
#
#                                 Purpose
#
#
#
#
#
#
#
#
#
#
#
# Jordan Careers
#
#
#
#
#
#
#
# Converse Careers
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
#
#
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
    """ 
    ### SCRAPPRD TEXT FROM WEBSITE
    {page_data}
    ### INSTRUCTION:
    the scrapped text is from the careers's page of a website.
    the job is to extract the job postings and return them in JSON format containing the 
    following keys: 'role', 'experience', 'skills' and 'description', only return the valid
    JSON.
    ### VALIS JSON (NO PREAMBLE):
    """
)

chain_extract = prompt_extract | llm
res = chain_extract.invoke(input={'page_data':page_data})
#print(res.content)
type(res.content)
# Out:
# str

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# [{'role': 'ADMINISTRATIVE ASSISTANT',
#   'experience': None,
#   'skills': None,
#   'description': 'ITCR-66395 Karnataka, Karnataka, India Business Operations'},
#  {'role': 'ATHLETE ADDETTO ALLE VENDITE 21H',
#   'experience': None,
#   'skills': None,
#   'description': 'CATEGORIA PROTETTA (L.68/99) - NFS Mantova Outlet Village'},
#  {'role': 'Abteilungsleiter (Coach)',
#   'experience': None,
#   'skills': None,
#   'description': '37.5h - Radolfzell am Bodensee'},
#  {'role': 'Abteilungsleiter (Coach)',
#   'experience': None,
#   'skills': None,
#   'description': '37,5h - NFS München Brunnthal'},
#  {'role': 'Abteilungsleiter',
#   'experience': None,
#   'skills': None,
#   'description': '38.5h - Nike Salzburg'},
#  {'role': 'Abteilungsleiter/in (Coach)',
#   'experience': None,
#   'skills': None,
#   'description': '100% - NFS Landquart'},
#  {'role': 'Account Executive Jordan',
#   'experience': None,
#   'skills': None,
#   'description': 'Pacific'},
# ...

# %%
type(json_res)
# Out:
# list

# %%
import pandas as pd 
df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack                                              Links
# 0                React, Node.js, MongoDB                https://example.com/react-portfolio
# 1               Angular,.NET, SQL Server              https://example.com/angular-portfolio
# 2      Vue.js, Ruby on Rails, PostgreSQL                  https://example.com/vue-portfolio
# 3                  Python, Django, MySQL               https://example.com/python-portfolio
# 4              Java, Spring Boot, Oracle                 https://example.com/java-portfolio
# 5             Flutter, Firebase, GraphQL              https://example.com/flutter-portfolio
# 6                  WordPress, PHP, MySQL            https://example.com/wordpress-portfolio
# 7                    Magento, PHP, MySQL              https://example.com/magento-portfolio
# 8         React Native, Node.js, MongoDB         https://example.com/react-native-portfolio
# ...

# %%
import chromadb 
import uuid

client  = chromadb.PersistentClient('verctorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=["Techstack"],
                      metadatas={"links": row["Links"]},
                      ids=[str(uuid.uuid4())])

# %%
links = collection.query(query_texts=["Experience in python", "Experience in React"], n_results=2).get('metadata')

# %%
job = json_res
job[1]
# Out:
# {'role': 'ATHLETE ADDETTO ALLE VENDITE 21H',
#  'experience': None,
#  'skills': None,
#  'description': 'CATEGORIA PROTETTA (L.68/99) - NFS Mantova Outlet Village'}

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Mohan, a business development executive at AtliQ. AtliQ is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of AtliQ 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
        Remember you are Mohan, BDE at AtliQ. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
    )
chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Enhance Operational Efficiency with AtliQ's Automated Solutions
#
# Dear Hiring Manager,
#
# I came across the job postings for various roles at your esteemed organization, including Administrative Assistant, Athlete Addetto Alle Vendite, Abteilungsleiter, and Account Executive, among others. As a Business Development Executive at AtliQ, I noticed that many of these roles require streamlined processes, efficient operations, and seamless integration of business functions.
#
# At AtliQ, we specialize in providing AI-powered and software consulting services that cater to the unique needs of businesses like yours. Our expertise lies in developing tailored solutions that foster scalability, process optimization, cost reduction, and heightened overall efficiency. Our team of experts can help you automate tasks, enhance data management, and improve collaboration across departments.
#
# With our automated tools and software solutions, you can:
#
# ...
